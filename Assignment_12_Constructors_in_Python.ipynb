# %% [markdown]
# <a href="https://colab.research.google.com/github/SathvikaP18/Python-Assignments/blob/main/Assignment_12_Constructors_in_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Assignment-12: Constructors in Python

# %% [markdown]
# 1. Default and Parameterized Constructors

# %%
# 1. Default and Parameterized Constructors

class Student:
    def __init__(self, name="Unknown", age=0):
        self.name = name
        self.age = age

    def display(self):
        print("Name:", self.name)
        print("Age :", self.age)
        print("-" * 20)

# Default constructor
obj1 = Student()
# One-argument constructor
obj2 = Student("Sathvika")
# Two-argument constructor
obj3 = Student("Ashwini", 22)

obj1.display()
obj2.display()
obj3.display()
# Out:
# Name: Unknown
# Age : 0
# --------------------
# Name: Sathvika
# Age : 0
# --------------------
# Name: Ashwini
# Age : 22
# --------------------

# %% [markdown]
# 2. Calling Parent Constructor

# %%
class College:
    def __init__(self, college_name):
        self.college_name = college_name
        print("College Constructor Called")

class Student(College):
    def __init__(self, college_name, student_name):
        super().__init__(college_name)
        self.student_name = student_name
        print("Student Constructor Called")

    def display(self):
        print("College Name:", self.college_name)
        print("Student Name:", self.student_name)

obj = Student("CMR Engineering College", "Sathvika")
obj.display()
# Out:
# College Constructor Called
# Student Constructor Called
# College Name: CMR Engineering College
# Student Name: Sathvika

# %% [markdown]
# 3. Simulating Access Levels

# %%
class Demo:
    def __init__(self):
        self.public = "Public Variable"
        self._protected = "Protected Variable"
        self.__private = "Private Variable"
obj = Demo()
print("Public:", obj.public)
print("Protected:", obj._protected)
try:
    print(obj.__private)
except AttributeError:
    print("Private variable cannot be accessed directly.")
print("Private using name mangling:", obj._Demo__private)
# Out:
# Public: Public Variable
# Protected: Protected Variable
# Private variable cannot be accessed directly.
# Private using name mangling: Private Variable

# %% [markdown]
# 4. Constructor Attributes Concept

# %%
class Student:
    def __init__(self, name, age, course):
        self.name = name
        self.age = age
        self.course = course
obj = Student("Sathvika", 21, "B.Tech IT")
print("Name :", obj.name)
print("Age  :", obj.age)
print("Course:", obj.course)
# Out:
# Name : Sathvika
# Age  : 21
# Course: B.Tech IT

# %% [markdown]
# 5. Using __str__() for Better Output

# %%
class Student:
    def __init__(self, name, age):
        self.name = name
        self.age = age
    def __str__(self):
        return f"Student(Name={self.name}, Age={self.age})"
obj = Student("Sathvika", 21)
print(obj)
# Out:
# Student(Name=Sathvika, Age=21)

# %% [markdown]
# 6. Constructor with *args

# %%
class Numbers:
    def __init__(self, *args):
        self.values = args
    def display(self):
        print("Values:", self.values)
obj = Numbers(10, 20, 30, 40, 50)
obj.display()
# Out:
# Values: (10, 20, 30, 40, 50)

# %% [markdown]
# 7. Real-World Example

# %%
class Employee:
    def __init__(self, name, emp_id, salary):
        self.name = name
        self.emp_id = emp_id
        self.salary = salary
    def display(self):
        print("Employee Name :", self.name)
        print("Employee ID   :", self.emp_id)
        print("Salary        :", self.salary)
        print("-" * 30)
emp1 = Employee("Sathvika", 101, 35000)
emp2 = Employee("Ashwini", 102, 42000)
emp3 = Employee("Renu", 103, 50000)

emp1.display()
emp2.display()
emp3.display()
# Out:
# Employee Name : Sathvika
# Employee ID   : 101
# Salary        : 35000
# ------------------------------
# Employee Name : Ashwini
# Employee ID   : 102
# Salary        : 42000
# ------------------------------
# Employee Name : Renu
# Employee ID   : 103
# Salary        : 50000
# ------------------------------
