# %% [markdown]
# <a href="https://colab.research.google.com/github/SathvikaP18/Python-Assignments/blob/main/Assignment_14_Exception_Handling_in_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Assignment-14: Exception Handling in Python

# %% [markdown]
# 1. Generate an Exception

# %%
a = 10
b = 0
result = a / b
print(result)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipykernel_1420/3948928082.py in <cell line: 0>()
#       2 b = 0
#       3
# ----> 4 result = a / b
#       5 print(result)
#
# ZeroDivisionError: division by zero

# %% [markdown]
# 2. Handle the Exception

# %%
a = 10
b = 0

try:
    result = a / b
    print("Result:", result)
except ZeroDivisionError:
    print("Error: Cannot divide by zero.")
# Out:
# Error: Cannot divide by zero.

# %% [markdown]
# 3. Multiple Except Blocks

# %%
try:
    num1 = int(input("Enter first number: "))
    num2 = int(input("Enter second number: "))
    result = num1 / num2
    print("Result:", result)
except ZeroDivisionError:
    print("Error: Division by zero is not allowed.")
except ValueError:
    print("Error: Please enter valid integers.")
# Out:
# Enter first number: 20
# Enter second number: 5
# Result: 4.0

# %% [markdown]
# 4. Raise an Exception Manually

# %%
def check_age(age):
    if age < 18:
        raise Exception("Age must be 18 or above.")
    print("Eligible.")
try:
    check_age(16)
except Exception as e:
    print(e)
# Out:
# Age must be 18 or above.

# %% [markdown]
# 5. Function That Raises Exception

# %% [markdown]
# Without Handling

# %%
def show_error():
    raise Exception("This is a custom exception.")
show_error()
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# /tmp/ipykernel_1420/2830691012.py in <cell line: 0>()
#       1 def show_error():
#       2     raise Exception("This is a custom exception.")
# ----> 3 show_error()
#
# /tmp/ipykernel_1420/2830691012.py in show_error()
#       1 def show_error():
# ----> 2     raise Exception("This is a custom exception.")
#       3 show_error()
#
# Exception: This is a custom exception.

# %% [markdown]
# With Handling

# %%
def show_error():
    raise Exception("This is a custom exception.")
try:
    show_error()
except Exception as e:
    print("Handled:", e)
# Out:
# Handled: This is a custom exception.

# %% [markdown]
# 6. Create Your Own Exception

# %%
class InsufficientBalanceError(Exception):
    pass

balance = 500
withdraw = 700

try:
    if withdraw > balance:
        raise InsufficientBalanceError("Insufficient Balance.")
    balance -= withdraw
    print("Remaining Balance:", balance)

except InsufficientBalanceError as e:
    print(e)
# Out:
# Insufficient Balance.

# %% [markdown]
# 7. Using finally

# %%
file = None
try:
    file = open("sample.txt", "w")
    file.write("Hello Python")
    print("Data written successfully.")
except Exception as e:
    print(e)
finally:
    if file:
        file.close()
    print("File closed.")
# Out:
# Data written successfully.
# File closed.

# %% [markdown]
# 8. File Not Found

# %%
try:
    file = open("unknown.txt", "r")

except FileNotFoundError:
    print("File not found.")
# Out:
# File not found.

# %% [markdown]
# 9. Type Error

# %%
try:
    result = 10 + "Python"
    print(result)

except TypeError:
    print("Type Error occurred.")
# Out:
# Type Error occurred.

# %% [markdown]
# 10. Attribute Error

# %%
class Student:
    def __init__(self):
        self.name = "Riya"
obj = Student()
try:
    print(obj.age)
except AttributeError:
    print("Attribute does not exist.")
# Out:
# Attribute does not exist.

# %% [markdown]
# 11. Index Error

# %%
numbers = [10, 20, 30]
try:
    print(numbers[5])
except IndexError:
    print("Index out of range.")
# Out:
# Index out of range.

# %% [markdown]
# 12. Use else Block

# %%
try:
    num1 = 20
    num2 = 5
    result = num1 / num2
except ZeroDivisionError:
    print("Division by zero.")
else:
    print("Result:", result)
# Out:
# Result: 4.0

# %% [markdown]
# 13. Logging Errors

# %%
import logging
logging.basicConfig(filename="error.log", level=logging.ERROR)
try:
    result = 10 / 0
except Exception as e:
    logging.error("An error occurred: %s", e)
    print("Error logged successfully.")
# Out:
# ERROR:root:An error occurred: division by zero
# Error logged successfully.

# %% [markdown]
# 14. Input Validation System

# %%
while True:
    try:
        number = int(input("Enter an integer: "))
        print("You entered:", number)
        break
    except ValueError:
        print("Invalid input. Please enter a valid integer.")
# Out:
# Enter an integer: 2
# You entered: 2
