# %% [markdown]
# <a href="https://colab.research.google.com/github/SathvikaP18/Python-Assignments/blob/main/Assignment_9_Abstract_Classes_in_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Assignment-9: Abstract Classes in Python

# %% [markdown]
# 1. Abstract and Non-Abstract Methods

# %%
from abc import ABC, abstractmethod
class Animal(ABC):
    @abstractmethod
    def sound(self):
        pass
    def sleep(self):
        print("Animals need sleep.")

# %% [markdown]
# 2. Create a Child Class

# %%
from abc import ABC, abstractmethod
class Animal(ABC):
    @abstractmethod
    def sound(self):
        pass
    def sleep(self):
        print("Animals need sleep.")
class Dog(Animal):
    def sound(self):
        print("Dog barks.")

# %% [markdown]
# 3. Access Non-Abstract Method via Child Object

# %%
from abc import ABC, abstractmethod
class Animal(ABC):
    @abstractmethod
    def sound(self):
        pass
    def sleep(self):
        print("Animals need sleep.")
class Dog(Animal):
    def sound(self):
        print("Dog barks.")
d = Dog()
d.sleep()
# Out:
# Animals need sleep.

# %% [markdown]
# 4. Call Abstract Method Implementation

# %%
from abc import ABC, abstractmethod
class Animal(ABC):
    @abstractmethod
    def sound(self):
        pass
    def sleep(self):
        print("Animals need sleep.")
class Dog(Animal):
    def sound(self):
        print("Dog barks.")
d = Dog()
d.sleep()
d.sound()
# Out:
# Animals need sleep.
# Dog barks.

# %% [markdown]
# 5. Attempt to Instantiate Abstract Class

# %%
from abc import ABC, abstractmethod
class Animal(ABC):
    @abstractmethod
    def sound(self):
        pass
a = Animal()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_860/1725907234.py in <cell line: 0>()
#       4     def sound(self):
#       5         pass
# ----> 6 a = Animal()
#
# TypeError: Can't instantiate abstract class Animal without an implementation for abstract method 'sound'

# %% [markdown]
# An abstract class contains one or more abstract methods. Python does not allow creating objects of an abstract class directly because the abstract methods do not have implementations.

# %% [markdown]
# 6. Multiple Abstract Methods

# %%
from abc import ABC, abstractmethod
class Animal(ABC):
    @abstractmethod
    def sound(self):
        pass
    @abstractmethod
    def move(self):
        pass
class Dog(Animal):
    def sound(self):
        print("Dog barks.")
    def move(self):
        print("Dog runs.")
d = Dog()
d.sound()
d.move()
# Out:
# Dog barks.
# Dog runs.

# %% [markdown]
# 7. Real-World Example (Shape)

# %%
from abc import ABC, abstractmethod
class Shape(ABC):
    @abstractmethod
    def area(self):
        pass
    def display(self):
        print("Calculating Area")
class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius
    def area(self):
        print("Area of Circle =", 3.14 * self.radius * self.radius)
class Rectangle(Shape):
    def __init__(self, length, width):
        self.length = length
        self.width = width
    def area(self):
        print("Area of Rectangle =", self.length * self.width)
c = Circle(5)
c.display()
c.area()

r = Rectangle(10, 4)
r.display()
r.area()
# Out:
# Calculating Area
# Area of Circle = 78.5
# Calculating Area
# Area of Rectangle = 40

# %% [markdown]
# 8. Partial Implementation

# %%
from abc import ABC, abstractmethod
class Animal(ABC):
    @abstractmethod
    def sound(self):
        pass
    @abstractmethod
    def move(self):
        pass
class Cat(Animal):
    def sound(self):
        print("Cat meows.")
c = Cat()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_860/1709417298.py in <cell line: 0>()
#      10     def sound(self):
#      11         print("Cat meows.")
# ---> 12 c = Cat()
#
# TypeError: Can't instantiate abstract class Cat without an implementation for abstract method 'move'
